# %%
'''import pandas as pd
import numpy as np
df = pd.read_csv(r'C:\Users\DSimonov\Desktop\aa\sdv.csv', encoding ="cp866", decimal ="." )
df.columns =[ 'regn', 'plan', 'num_sc', 'a_p', 'vr', 'vv','vitg', 'ora', 'ova','oitga', 'orp', 'ovp','oitgp', 'ir', 'iv','iitg', 'dt', 'priz']
for col in ['plan', 'num_sc', 'a_p']:
    df[col] = df[col].astype('object')
for col in ['regn', 'vr', 'vv','vitg','ora', 'ova','oitga', 'orp', 'ovp','oitgp', 'ir', 'iv','iitg']:
    df[col] = df[col].replace('None', np.nan, regex=True)
    df[col] = df[col].fillna(0)
    df[col] = pd.to_numeric(df[col].astype('float64'))
    df[col] = pd.to_numeric(df[col].astype('int64'))
#    df[ pd.to_numeric(df[col], errors='coerce').isnull()]
#    df[col] = df[col].to_numeric(df[col].astype('int64'))

df['dt'] =  pd.to_datetime(df['dt'])
df.info()
print(df.head())
print(df.describe())'''

# %%
# %%time
import re
import os
import pandas as pd
import numpy as np
i=1
df=pd.DataFrame()
print("Phase 3. Converting all CSV files into Pandas Database.")
for subdir, dirs, files in os.walk(r'C:\Users\DSimonov\Desktop\aa\101'):
    for file in files:
        filepath = subdir + os.sep + file
        print(f"Now begin to process {i} of {len(files)} files, ({int(i/(len(files))*100)}%)")
        df_temp = pd.read_csv(filepath, encoding ="cp866", decimal ="." )
        df_temp.columns =[ 'regn', 'plan', 'num_sc', 'a_p', 'vr', 'vv','vitg', 'ora', 'ova','oitga', 'orp', 'ovp','oitgp', 'ir', 'iv','iitg', 'dt', 'priz']
        for col in ['plan', 'num_sc', 'a_p']:
            df_temp[col] = df_temp[col].astype('object')
        for col in ['regn', 'vr', 'vv','vitg','ora', 'ova','oitga', 'orp', 'ovp','oitgp', 'ir', 'iv','iitg']:
            df_temp[col] = df_temp[col].replace('None', np.nan, regex=True)
            df_temp[col] = df_temp[col].fillna(0)
            df_temp[col] = pd.to_numeric(df_temp[col].astype('float64'))
            df_temp[col] = pd.to_numeric(df_temp[col].astype('int64'))
            df_temp['dt'] =  pd.to_datetime(df_temp['dt'])
        df = df.append(df_temp, ignore_index=True)
        print(f"Done!")
        i+=1
print(f"Everything was imported. Now we have {df.shape[0]} rows in file.")
print("Saving to CSV")
df.to_csv(r'C:\Users\DSimonov\Desktop\aa\total-101.csv', encoding = 'utf-8', index = False)
print("Phase 3 completed!")
# Out:
# Phase 3. Converting all CSV files into Pandas Database.
# Now begin to process 1 of 148 files, (0%)
# <string>:2: DtypeWarning: Columns (4,5,6,7,8,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
# Done!
# Now begin to process 2 of 148 files, (1%)
# Done!
# Now begin to process 3 of 148 files, (2%)
# Done!
# Now begin to process 4 of 148 files, (2%)
# Done!
# Now begin to process 5 of 148 files, (3%)
# Done!
# Now begin to process 6 of 148 files, (4%)
# Done!
# Now begin to process 7 of 148 files, (4%)
# Done!
# Now begin to process 8 of 148 files, (5%)
# Done!
# Now begin to process 9 of 148 files, (6%)
# Done!
# Now begin to process 10 of 148 files, (6%)
# Done!
# Now begin to process 11 of 148 files, (7%)
# Done!
# Now begin to process 12 of 148 files, (8%)
# Done!
# Now begin to process 13 of 148 files, (8%)
# Done!
# Now begin to process 14 of 148 files, (9%)
# Done!
# Now begin to process 15 of 148 files, (10%)
# Done!
# Now begin to process 16 of 148 files, (10%)
# Done!
# Now begin to process 17 of 148 files, (11%)
# Done!
# Now begin to process 18 of 148 files, (12%)
# Done!
# Now begin to process 19 of 148 files, (12%)
# Done!
# Now begin to process 20 of 148 files, (13%)
# Done!
# Now begin to process 21 of 148 files, (14%)
# Done!
# Now begin to process 22 of 148 files, (14%)
# Done!
# Now begin to process 23 of 148 files, (15%)
# Done!
# Now begin to process 24 of 148 files, (16%)
# Done!
# Now begin to process 25 of 148 files, (16%)
# Done!
# Now begin to process 26 of 148 files, (17%)
# Done!
# Now begin to process 27 of 148 files, (18%)
# Done!
# Now begin to process 28 of 148 files, (18%)
# Done!
# Now begin to process 29 of 148 files, (19%)
# Done!
# Now begin to process 30 of 148 files, (20%)
# Done!
# Now begin to process 31 of 148 files, (20%)
# Done!
# Now begin to process 32 of 148 files, (21%)
# Done!
# Now begin to process 33 of 148 files, (22%)
# Done!
# Now begin to process 34 of 148 files, (22%)
# Done!
# Now begin to process 35 of 148 files, (23%)
# Done!
# Now begin to process 36 of 148 files, (24%)
# Done!
# Now begin to process 37 of 148 files, (25%)
# Done!
# Now begin to process 38 of 148 files, (25%)
# Done!
# Now begin to process 39 of 148 files, (26%)
# Done!
# Now begin to process 40 of 148 files, (27%)
# Done!
# Now begin to process 41 of 148 files, (27%)
# Done!
# Now begin to process 42 of 148 files, (28%)
# Done!
# Now begin to process 43 of 148 files, (29%)
# Done!
# Now begin to process 44 of 148 files, (29%)
# Done!
# Now begin to process 45 of 148 files, (30%)
# Done!
# Now begin to process 46 of 148 files, (31%)
# Done!
# Now begin to process 47 of 148 files, (31%)
# Done!
# Now begin to process 48 of 148 files, (32%)
# Done!
# Now begin to process 49 of 148 files, (33%)
# Done!
# Now begin to process 50 of 148 files, (33%)
# Done!
# Now begin to process 51 of 148 files, (34%)
# Done!
# Now begin to process 52 of 148 files, (35%)
# Done!
# Now begin to process 53 of 148 files, (35%)
# Done!
# Now begin to process 54 of 148 files, (36%)
# Done!
# Now begin to process 55 of 148 files, (37%)
# Done!
# Now begin to process 56 of 148 files, (37%)
# Done!
# Now begin to process 57 of 148 files, (38%)
# Done!
# Now begin to process 58 of 148 files, (39%)
# Done!
# Now begin to process 59 of 148 files, (39%)
# Done!
# Now begin to process 60 of 148 files, (40%)
# Done!
# Now begin to process 61 of 148 files, (41%)
# Done!
# Now begin to process 62 of 148 files, (41%)
# Done!
# Now begin to process 63 of 148 files, (42%)
# Done!
# Now begin to process 64 of 148 files, (43%)
# Done!
# Now begin to process 65 of 148 files, (43%)
# Done!
# Now begin to process 66 of 148 files, (44%)
# Done!
# Now begin to process 67 of 148 files, (45%)
# Done!
# Now begin to process 68 of 148 files, (45%)
# Done!
# Now begin to process 69 of 148 files, (46%)
# Done!
# Now begin to process 70 of 148 files, (47%)
# Done!
# Now begin to process 71 of 148 files, (47%)
# Done!
# Now begin to process 72 of 148 files, (48%)
# Done!
# Now begin to process 73 of 148 files, (49%)
# Done!
# Now begin to process 74 of 148 files, (50%)
# Done!
# Now begin to process 75 of 148 files, (50%)
# Done!
# Now begin to process 76 of 148 files, (51%)
# Done!
# Now begin to process 77 of 148 files, (52%)
# Done!
# Now begin to process 78 of 148 files, (52%)
# Done!
# Now begin to process 79 of 148 files, (53%)
# Done!
# Now begin to process 80 of 148 files, (54%)
# Done!
# Now begin to process 81 of 148 files, (54%)
# Done!
# Now begin to process 82 of 148 files, (55%)
# Done!
# Now begin to process 83 of 148 files, (56%)
# Done!
# Now begin to process 84 of 148 files, (56%)
# Done!
# Now begin to process 85 of 148 files, (57%)
# Done!
# Now begin to process 86 of 148 files, (58%)
# Done!
# Now begin to process 87 of 148 files, (58%)
# Done!
# Now begin to process 88 of 148 files, (59%)
# Done!
# Now begin to process 89 of 148 files, (60%)
# Done!
# Now begin to process 90 of 148 files, (60%)
# Done!
# Now begin to process 91 of 148 files, (61%)
# Done!
# Now begin to process 92 of 148 files, (62%)
# Done!
# Now begin to process 93 of 148 files, (62%)
# Done!
# Now begin to process 94 of 148 files, (63%)
# Done!
# Now begin to process 95 of 148 files, (64%)
# Done!
# Now begin to process 96 of 148 files, (64%)
# Done!
# Now begin to process 97 of 148 files, (65%)
# Done!
# Now begin to process 98 of 148 files, (66%)
# Done!
# Now begin to process 99 of 148 files, (66%)
# Done!
# Now begin to process 100 of 148 files, (67%)
# Done!
# Now begin to process 101 of 148 files, (68%)
# Done!
# Now begin to process 102 of 148 files, (68%)
# Done!
# Now begin to process 103 of 148 files, (69%)
# Done!
# Now begin to process 104 of 148 files, (70%)
# Done!
# Now begin to process 105 of 148 files, (70%)
# Done!
# Now begin to process 106 of 148 files, (71%)
# Done!
# Now begin to process 107 of 148 files, (72%)
# Done!
# Now begin to process 108 of 148 files, (72%)
# Done!
# Now begin to process 109 of 148 files, (73%)
# Done!
# Now begin to process 110 of 148 files, (74%)
# Done!
# Now begin to process 111 of 148 files, (75%)
# Done!
# Now begin to process 112 of 148 files, (75%)
# Done!
# Now begin to process 113 of 148 files, (76%)
# Done!
# Now begin to process 114 of 148 files, (77%)
# Done!
# Now begin to process 115 of 148 files, (77%)
# Done!
# Now begin to process 116 of 148 files, (78%)
# Done!
# Now begin to process 117 of 148 files, (79%)
# Done!
# Now begin to process 118 of 148 files, (79%)
# Done!
# Now begin to process 119 of 148 files, (80%)
# Done!
# Now begin to process 120 of 148 files, (81%)
# Done!
# Now begin to process 121 of 148 files, (81%)
# Done!
# Now begin to process 122 of 148 files, (82%)
# Done!
# Now begin to process 123 of 148 files, (83%)
# Done!
# Now begin to process 124 of 148 files, (83%)
# Done!
# Now begin to process 125 of 148 files, (84%)
# Done!
# Now begin to process 126 of 148 files, (85%)
# Done!
# Now begin to process 127 of 148 files, (85%)
# Done!
# Now begin to process 128 of 148 files, (86%)
# Done!
# Now begin to process 129 of 148 files, (87%)
# Done!
# Now begin to process 130 of 148 files, (87%)
# Done!
# Now begin to process 131 of 148 files, (88%)
# Done!
# Now begin to process 132 of 148 files, (89%)
# Done!
# Now begin to process 133 of 148 files, (89%)
# Done!
# Now begin to process 134 of 148 files, (90%)
# Done!
# Now begin to process 135 of 148 files, (91%)
# Done!
# Now begin to process 136 of 148 files, (91%)
# Done!
# Now begin to process 137 of 148 files, (92%)
# Done!
# Now begin to process 138 of 148 files, (93%)
# Done!
# Now begin to process 139 of 148 files, (93%)
# Done!
# Now begin to process 140 of 148 files, (94%)
# Done!
# Now begin to process 141 of 148 files, (95%)
# Done!
# Now begin to process 142 of 148 files, (95%)
# Done!
# Now begin to process 143 of 148 files, (96%)
# Done!
# Now begin to process 144 of 148 files, (97%)
# Done!
# Now begin to process 145 of 148 files, (97%)
# Done!
# Now begin to process 146 of 148 files, (98%)
# Done!
# Now begin to process 147 of 148 files, (99%)
# Done!
# Now begin to process 148 of 148 files, (100%)
# Done!
# Everything was imported. Now we have 20419926 rows in file.
# Saving to CSV
# Phase 3 completed!
# Wall time: 27min 24s

# %%
# %%time
import pandas as pd
print("Loading CSV with data")
df = pd.read_csv(r'C:\Users\DSimonov\Desktop\aa\total-101.csv')
print("Converting fields into proper format.")
#for col in df['plan', 'num_sc', 'a_p']:
#    df[col] = df[col].astype('object')
df['a_p'] = df['a_p'].astype('object')
df['dt'] =  pd.to_datetime(df['dt'])
print("Done! now we have {df.shape[0]} rows in dataframe.")

# %%
df.tail()

# %%
# %%time
reg_number = 2880
date = ['2018-01-01']
acc=[20202]
df_temp1 = df.loc[df['regn'] == reg_number & df['dt'].isin(date) & df['num_sc'].isin(acc)]['iitg']

# %%
a = df_temp1.values[0]
a

# %%
# %%time
df2 = df.loc[df['regn'] == reg_number]

# %%
# %%time
df2.head()

# %%
# %%time
date = ['2011-01-01']
acc=[20202, 30102, 40817, 47423]
df3 = df2.loc[df2['dt'].isin(date)& df2['num_sc'].isin(acc)]
df4 = df3[['num_sc','iitg']]
print(df4.head())
a = df4['iitg'].sum(axis = 0)
print(a)

# %%
df_loans = pd.read_csv(r'C:\Users\DSimonov\Desktop\aa\loans_pns.csv')
df_loans.head()

# %%
'''по счетам погашенных кредитов (учтенных
векселей)'''
redeemed_loans = pd.read_csv(r'C:\Users\DSimonov\Desktop\aa\loans_pns.csv')
redeemed_loans.head()

'''общему объему денежных средств, поступивших на корреспондентские счета кредитной
организации (дебетовые обороты за месяц по счетам НОСТРО)'''

nostro = pd.read_csv(r'C:\Users\DSimonov\Desktop\aa\nostro.csv')
nostro.head()

# %%
def last_report_date(reg_number):
    date = max(df.loc[df['regn'] == reg_number]['dt'])
    return date

# %%
# %%time
print(last_report_date (880))

# %%
# %%time
print(df.head())
df_temp12 = df.loc[df['regn'] == 2880]
df_temp13 = df_temp12.groupby(level=0)['dt'].min()
date = df_temp13.values[0]
print(date)

# %%
# %%time
df['dt'] = pd.to_datetime(df['dt'])
df.info()

# %%
# %%time
print(df.head())
date = max(df.loc[df['regn'] == 2880]['dt'])
print(date)
